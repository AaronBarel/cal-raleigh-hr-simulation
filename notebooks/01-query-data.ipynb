# %% [markdown]
# # This notebook is for exploring pybaseball and testing the src/data module

# %% [markdown]
# ## Investigating batting_stats from fangraphs

# %%
from pybaseball import playerid_lookup, batting_stats

# %%
playerid_lookup('raleigh', 'cal')
# Out:
# Gathering player lookup table. This may take a moment.
#   name_last name_first  ...  mlb_played_first mlb_played_last
# 0   raleigh        cal  ...            2021.0          2025.0
#
# [1 rows x 8 columns]

# %%
df_bat_stats_24 = batting_stats(2024) # fangraphs data

# %%
df_bat_stats_24.head(5)
# Out:
#     IDfg  Season              Name Team  Age  ...   CSW%    xBA   xSLG  xwOBA  L-WAR
# 0  15640    2024       Aaron Judge  NYY   32  ...  0.267  0.310  0.723  0.479   11.6
# 3  25764    2024    Bobby Witt Jr.  KCR   24  ...  0.236  0.315  0.576  0.407   10.4
# 1  19755    2024     Shohei Ohtani  LAD   29  ...  0.269  0.314  0.660  0.442    9.4
# 2  20123    2024         Juan Soto  NYY   25  ...  0.263  0.316  0.646  0.462    8.0
# 9  26289    2024  Gunnar Henderson  BAL   23  ...  0.265  0.283  0.492  0.374    8.2
#
# [5 rows x 320 columns]

# %%
df_bat_stats_24[df_bat_stats_24['Name'] == 'Cal Raleigh']
# Out:
#      IDfg  Season         Name Team  Age  ...   CSW%    xBA   xSLG  xwOBA  L-WAR
# 74  21534    2024  Cal Raleigh  SEA   27  ...  0.264  0.233  0.476  0.346    5.8
#
# [1 rows x 320 columns]

# %%
list(df_bat_stats_24.columns)
# Out:
# ['IDfg',
#  'Season',
#  'Name',
#  'Team',
#  'Age',
#  'G',
#  'AB',
#  'PA',
#  'H',
#  '1B',
#  '2B',
#  '3B',
#  'HR',
#  'R',
#  'RBI',
#  'BB',
#  'IBB',
#  'SO',
#  'HBP',
#  'SF',
#  'SH',
#  'GDP',
#  'SB',
#  'CS',
#  'AVG',
#  'GB',
#  'FB',
#  'LD',
#  'IFFB',
#  'Pitches',
#  'Balls',
#  'Strikes',
#  'IFH',
#  'BU',
#  'BUH',
#  'BB%',
#  'K%',
#  'BB/K',
#  'OBP',
#  'SLG',
#  'OPS',
#  'ISO',
#  'BABIP',
#  'GB/FB',
#  'LD%',
#  'GB%',
#  'FB%',
#  'IFFB%',
#  'HR/FB',
#  'IFH%',
#  'BUH%',
#  'wOBA',
#  'wRAA',
#  'wRC',
#  'Bat',
#  'Fld',
#  'Rep',
#  'Pos',
#  'RAR',
#  'WAR',
#  'Dol',
#  'Spd',
#  'wRC+',
#  'WPA',
#  '-WPA',
#  '+WPA',
#  'RE24',
#  'REW',
#  'pLI',
#  'phLI',
#  'PH',
#  'WPA/LI',
#  'Clutch',
#  'FB% (Pitch)',
#  'FBv',
#  'SL%',
#  'SLv',
#  'CT%',
#  'CTv',
#  'CB%',
#  'CBv',
#  'CH%',
#  'CHv',
#  'SF%',
#  'SFv',
#  'KN%',
#  'KNv',
#  'XX%',
#  'PO%',
#  'wFB',
#  'wSL',
#  'wCT',
#  'wCB',
#  'wCH',
#  'wSF',
#  'wKN',
#  'wFB/C',
# ...

# %%
columns_for_analysis = [
    'Season',
    'Name',
    'Team',
    'Age',
    'G',
    'AB',
    'PA',
    'HR',
    'BB%',
    'ISO',
    'SLG',
    'Barrel%',
    'Hard%',
    'xSLG'
]

# %%
df_bat_stats_24[columns_for_analysis]
# Out:
#      Season               Name   Team  Age  ...    SLG  Barrel%  Hard%   xSLG
# 0      2024        Aaron Judge    NYY   32  ...  0.701    0.269  0.477  0.723
# 3      2024     Bobby Witt Jr.    KCR   24  ...  0.588    0.143  0.353  0.576
# 1      2024      Shohei Ohtani    LAD   29  ...  0.646    0.214  0.443  0.660
# 2      2024          Juan Soto    NYY   25  ...  0.569    0.197  0.430  0.646
# 9      2024   Gunnar Henderson    BAL   23  ...  0.529    0.112  0.434  0.492
# ..      ...                ...    ...  ...  ...    ...      ...    ...    ...
# 111    2024  Andrew Benintendi    CHW   29  ...  0.396    0.063  0.307  0.389
# 114    2024      Adolis Garcia    TEX   31  ...  0.400    0.122  0.364  0.413
# 112    2024          Ty France  - - -   29  ...  0.365    0.073  0.286  0.387
# 125    2024  Christopher Morel  - - -   25  ...  0.346    0.102  0.336  0.399
# 122    2024   Bryan De La Cruz  - - -   27  ...  0.384    0.093  0.327  0.419
#
# [129 rows x 14 columns]

# %%
cr_df = batting_stats(start_season = 2021, end_season = 2024)
cr_df = cr_df[cr_df['Name'] == 'Cal Raleigh']
cr_df = cr_df[columns_for_analysis]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 3
#       1 cr_df = batting_stats(start_season = 2021, end_season = 2024, ind = 0)
#       2 cr_df = cr_df[cr_df['Name'] == 'Cal Raleigh']
# ----> 3 cr_df = cr_df[columns_for_analysis]
#
# File ~/virtualenvs/mcmc-baseball/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File ~/virtualenvs/mcmc-baseball/lib/python3.12/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
cr_df
# Out:
#      Season         Name Team  Age    G  ...    ISO    SLG  Barrel%  Hard%  xSLG
# 331    2024  Cal Raleigh  SEA   27  153  ...  0.216  0.436    0.154  0.394   NaN
# 300    2023  Cal Raleigh  SEA   26  145  ...  0.224  0.456    0.126  0.351   NaN
#
# [2 rows x 14 columns]
